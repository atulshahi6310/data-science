# %% [markdown]
# ## python revision

# %%
print("hey i am atul kumar shahi ")
# Out:
# hey i am atul kumar shahi

# %%
a = 20
b = 90.89
print(a , b)
# Out:
# 20 90.89

# %%
print(f" hey the valure of a is{a} and value of b  is{b}")
# Out:
#  hey the valure of a is20 and value of b  is90.89

# %%
c = int(b)
print(c)
# Out:
# 90

# %%
first_name  = "atul "
second_name = " shahi"
name = first_name + second_name
print(name)
# Out:
# atul  shahi

# %%
name.upper()
# Out:
# 'ATUL  SHAHI'

# %%
print(b//a)
# Out:
# 4.0

# %%
name.replace('a' ,'b')
# Out:
# 'btul  shbhi'

# %%
bank_balance = input("enter your bank balance")
print(bank_balance)
bank_total_balance = int(bank_balance)
if bank_total_balance < 2000 :
    print("hey it is a good for you if you add the more amount to mantain the balance ")
elif bank_total_balance < 100000 and bank_total_balance >2000:
    print(f"you get  total with intrest is { 5000}")
else:
    print(f" every month you get { (bank_total_balance *0.5)}")
# Out:
# enter your bank balance 80000
# 80000
# you get  total with intrest is 5000

# %% [markdown]
# # function in  python

# %%
# calcualate area of a shapes 
def shapes(l,b):
    area = l*b;
    print(f"area of the given rectangle is {area}")
shapes(222 ,888)
# Out:
# area of the given rectangle is 197136

# %%
for i in range(100, 150, 10):
    print(a * i)
# Out:
# 2000
# 2200
# 2400
# 2600
# 2800

# %% [markdown]
# # list

# %%
class_name = [1,2,3,4,5,6,7,8,9]
class_name.append(50)
class_name
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 50]

# %%
new_class = [5,8,9,55,8]
class_name.extend(new_class)
class_name
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 50, 5, 8, 9, 55, 8, 5, 8, 9, 55, 8]

# %% [markdown]
# # tuppel

# %%
 name =("atul", "rohan" , 'rashi' , "prinshu")

# %%
name
# Out:
# ('atul', 'rohan', 'rashi', 'prinshu')

# %%
t = (10, 20, 30)
print(t[1])  # 20
print(name[2])
# Out:
# 20
# rashi

# %%
t.count(10)
# Out:
# 1

# %%
print(t[1:3])
# Out:
# (20, 30)
