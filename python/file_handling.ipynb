# %% [markdown]
# # File handling

# %%
file_obj = open("abc.txt" , "a")
work = file_obj.write("hey i am a robot  & set this event to end of the  street ")
file_obj.close()

# %%
# different way  to above work is 
with open("abc.txt" , "r") as file :
    work = file.read()
    print(work)
# Out:
# hey i am a robothey i am a robothey i am a robothey i am a robot  & set this event to end of the  street hey i am a robot  & set this event to end of the  street

# %%
import os
if os.path.exists("abc.txt"):
    os.remove('abc.txt')
    print("file exist")
else:
    print('file not found 404!!')
# Out:
# file exist

# %%
#  shutil ...........................

# %%
import json

student_data = {
    "name": "Atul Shahi",
    "age": 19,
    "course": "B.Tech CSE (AI & ML)",
    "university": "Parul University",
    "skills": ["HTML", "CSS", "JavaScript", "Python"],
    "year": 1
}

json_string = json.dumps(student_data)  
with open("abc.txt" , 'a') as data:
    c = data.write(json_string)
    print(student_data)
# Out:
# {'name': 'Atul Shahi', 'age': 19, 'course': 'B.Tech CSE (AI & ML)', 'university': 'Parul University', 'skills': ['HTML', 'CSS', 'JavaScript', 'Python'], 'year': 1}

# %%
import json
with open("student.json" , "r") as file :
    obj = json.load(file )
    print(obj)
# Out:
# {'name': 'Atul Shahi', 'age': 19, 'course': 'B.Tech CSE (AI & ML)', 'university': 'Parul University', 'skills': ['HTML', 'CSS', 'JavaScript', 'Python'], 'year': 1}

# %% [markdown]
# # IN Python dump is use to load python objects to json
# ## and load is used to covert json obj to python obj

# %%
try: 
    a =10 
    b = 0
    c = a/b
except ArithmeticError as e:
    print(e)
else:
    print(c)
finally :
    print("we are done with that ")
# Out:
# division by zero
# we are done with that
