# %%
def start():
    while True :
        print("1 : add the product ")
        print("2 : buy the product ")
        print(" 3: show the product ")
        print("4 : generate the bill")
        print("5 :exit")
        select = int(input("plzz chose what you want to do ")

# %%
def add_items():
    pass

def show():

# %%
if __name__ == '__main__':
    cart = list()
    start()
